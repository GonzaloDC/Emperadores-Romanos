# %%
import pandas as pd
import numpy as np
from math import ceil
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('roman-emperors.csv')

# %%
df.head()
# Out:
#    Index                Name  \
# 0     52            Galerius
# 1     57            Lucinius
# 2     33            Philip I
# 3     36  Trebonianus Gallus
# 4     31            Balbinus
#
#                                            Full Name  \
# 0       CAESAR GALERIVS VALERIVS MAXIMIANVS AVGVSTVS
# 1            CAESAR GAIVS VALERIVS LICINIVS AVGVSTVS
# 2            CAESAR MARCVS IVLIVS PHILIPPVS AVGVSTVS
# 3    CAESAR GAIVS VIBIVS TREBONIANVS GALLVS AVGVSTVS
# 4  CAESAR DECIMVS CAELIVS CALVINVS BALBINVS PIVS ...
#
#                        Birth                      Death       Birth City  \
# 0  0260-01-01T00:53:28+00:53  0311-05-01T00:53:28+00:53        Romuliana
# 1  0250-01-01T00:53:28+00:53  0325-03-01T00:53:28+00:53  Felix Romuliana
# 2  0204-01-01T00:53:28+00:53  0249-10-01T00:53:28+00:53           Shahba
# 3  0206-01-01T00:53:28+00:53  0253-08-15T00:53:28+00:53              NaN
# 4  0178-01-01T00:53:28+00:53  0238-07-29T00:53:28+00:53              NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           68 non-null     int64
#  1   Name            68 non-null     object
#  2   Full Name       68 non-null     object
#  3   Birth           63 non-null     object
#  4   Death           68 non-null     object
#  5   Birth City      51 non-null     object
#  6   Birth Province  68 non-null     object
#  7   Succession      68 non-null     object
#  8   Reign Start     68 non-null     object
#  9   Reign End       68 non-null     object
#  10  Cause           68 non-null     object
#  11  Killer          68 non-null     object
#  12  Dynasty         68 non-null     object
#  13  Era             68 non-null     object
#  14  Notes           45 non-null     object
#  15  Verif           5 non-null      object
#  16  Image           68 non-null     object
# ...

# %% [markdown]
# ### Lo primero será ordenar los distintos emperadores por su indice, es decir, por orden cronológico en el que gobernaron:

# %%
df.sort_values(by='Index', inplace=True)

# %%
df.head()
# Out:
#     Index      Name                                     Full Name  \
# 15      1  Augustus         IMPERATOR CAESAR DIVI FILIVS AVGVSTVS
# 8       2  Tiberius  TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS
# 58      3  Caligula       GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS
# 53      4  Claudius  TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 50      5      Nero      NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS
#
#                         Birth                      Death Birth City  \
# 15  0062-09-23T00:53:28+00:53  0014-08-19T00:53:28+00:53       Rome
# 8   0041-11-16T00:53:28+00:53  0037-03-16T00:53:28+00:53       Rome
# 58  0012-08-31T00:53:28+00:53  0041-01-24T00:53:28+00:53    Antitum
# 53  0009-08-01T00:53:28+00:53  0054-10-13T00:53:28+00:53   Lugdunum
# 50  0037-12-15T00:53:28+00:53  0068-06-09T00:53:28+00:53    Antitum
#
#         Birth Province  Succession                Reign Start  \
# 15              Italia  Birthright  0026-01-16T00:53:28+00:53
# ...

# %%
df.tail(20)
# Out:
#                         Name  \
# Index
# 49                Diocletian
# 50                  Maximian
# 51             Constantius I
# 52                  Galerius
# 53                Severus II
# 54     Constantine the Great
# 55                 Maxentius
# 56              Maximinus II
# 57                  Lucinius
# 58            Constantine II
# 59            Constantius II
# 60                  Constans
# 61                  Vetranio
# 62                    Julian
# 63                    Jovian
# 64             Valentinian I
# 65                    Valens
# 66                   Gratian
# 67            Valentinian II
# 68              Theodosius I
#
#                                                Full Name Birth Death  \
# Index
# 49     CAESAR GAIVS AVRELIVS VALERIVS DIOCLETIANVS AV...  0244  0311
# 50     CAESAR MARCVS AVRELIVS VALERIVS MAXIMIANVS AVG...  0250  0310
# 51     CAESAR GAIVS FLAVIVS VALERIVS CONSTANTIVS AVGV...  0250  0306
# ...

# %% [markdown]
# ### Los siguientes pasos para organizar el dataframe serán:
# 1.Obtener sólo los años en las columnas de fechas.
#
# 2.intentar rellenar las columnas de Birth City y Birth Province
#
# 3.Eliminar las columnas que no nos interesan

# %%
df.isna().sum()
# Out:
# Index              0
# Name               0
# Full Name          0
# Birth              5
# Death              0
# Birth City        17
# Birth Province     0
# Succession         0
# Reign Start        0
# Reign End          0
# Cause              0
# Killer             0
# Dynasty            0
# Era                0
# Notes             23
# Verif             63
# Image              0
# Unnamed: 17       68
# Unnamed: 18       68
# Unnamed: 19       68
# dtype: int64

# %% [markdown]
# ### Se formatearán las columnas de las fechas para obtener sólo los años. Se hará en las columnas <i>"Birth"</i> , <i>"Death"</i>, <i>"Reign Start"</i> y <i>"Reign End"</i>

# %%
df['Birth'] = df['Birth'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])
df['Death'] = df['Death'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])
df['Reign Start'] = df['Reign Start'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])
df['Reign End'] = df['Reign End'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])

# %% [markdown]
# ### El siguiente paso sera rellenar las columnas (si es posible) <i>"Birth City"</i> y <i>"Birth Province"</i> en caso de que tengan valores nulos o valores unknown.

# %%
df.isna().sum()
# Out:
# Index              0
# Name               0
# Full Name          0
# Birth              5
# Death              0
# Birth City        17
# Birth Province     0
# Succession         0
# Reign Start        0
# Reign End          0
# Cause              0
# Killer             0
# Dynasty            0
# Era                0
# Notes             23
# Verif             63
# Image              0
# Unnamed: 17       68
# Unnamed: 18       68
# Unnamed: 19       68
# dtype: int64

# %%
df[df['Birth City'].isna()]
# Out:
#     Index                Name  \
# 20     27         Maximinus I
# 22     28           Gordian I
# 32     29          Gordian II
# 33     30            Pupienus
# 4      31            Balbinus
# 3      36  Trebonianus Gallus
# 63     37            Aemilian
# 62     38            Valerian
# 21     39           Gallienus
# 49     44             Florian
# 6      47            Numerian
# 7      48             Carinus
# 52     53          Severus II
# 65     55           Maxentius
# 64     56        Maximinus II
# 14     60            Constans
# 51     61            Vetranio
#
#                                             Full Name Birth Death Birth City  \
# 20       CAESAR GAIVS IVLIVS VERVS MAXIMINVS AVGVSTVS  0173  0238        NaN
# 22  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0159  0238        NaN
# 32  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0192  0238        NaN
# 33    CAESAR MARCVS CLODIVS PVPIENVS MAXIMVS AVGVSTVS  0178  0238        NaN
# ...

# %% [markdown]
# ### De los 17 valores NaN de Birth City, se tienen 7 en los que si que se conoce el 'Birth Province', por lo que se tomará la capital de dicha provincia como aproximación.

# %%
df.at[51,'Birth']=310
df.at[31,'Birth Province']='Italia'

# %%
df[df['Birth Province']=='Moesia']=df[df['Birth Province']=='Moesia'].fillna('Dardania')
df[df['Birth Province']=='Phrygia']=df[df['Birth Province']=='Phrygia'].fillna('Phrygia')
df[df['Birth Province']=='Italia']=df[df['Birth Province']=='Italia'].fillna('Rome')
df[df['Birth Province']=='Africa']=df[df['Birth Province']=='Africa'].fillna('Djerba')
df[df['Birth Province']=='Dacia Aureliana']=df[df['Birth Province']=='Dacia Aureliana'].fillna('Dacia Aureliana')
df[df['Birth Province']=='Thrace']=df[df['Birth Province']=='Thrace'].fillna('Thrace')

# %% [markdown]
# ### De los 10 restantes, se ha procedido a buscar el origen y rellenarlo:

# %%
df.loc[32,['Birth City','Birth Province']]='Phrygia' #Gordiano II
df.loc[4,['Birth City','Birth Province']]='Rome' #Balbinus
df.loc[49,'Birth City']='Terni' #florian
df.loc[49,'Birth Province']='Italia' #Severus II
df.loc[48,['Birth City','Birth Province']]='illyria' #Severus II

# %% [markdown]
# ### Lo siguiente sera eliminar las columnas que no necesitamos:
# - Notes
# - Verif
# - Image
# - Unnamed: 17
# - Unnamed: 18
# - Unnamed: 19

# %%
df.drop(['Notes','Verif','Image','Unnamed: 17','Unnamed: 18','Unnamed: 19'],axis=1, inplace=True)

# %%
df.head()
# Out:
#     Index      Name                                     Full Name Birth Death  \
# 15      1  Augustus         IMPERATOR CAESAR DIVI FILIVS AVGVSTVS  0062  0014
# 8       2  Tiberius  TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS  0041  0037
# 58      3  Caligula       GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS  0012  0041
# 53      4  Claudius  TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS  0009  0054
# 50      5      Nero      NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS  0037  0068
#
#    Birth City      Birth Province  Succession Reign Start Reign End  \
# 15       Rome              Italia  Birthright        0026      0014
# 8        Rome              Italia  Birthright        0014      0037
# 58    Antitum              Italia  Birthright        0037      0041
# 53   Lugdunum  Gallia Lugdunensis  Birthright        0041      0054
# 50    Antitum              Italia  Birthright        0054      0068
#
#             Cause         Killer         Dynasty         Era
# ...

# %% [markdown]
# ### Agregaremos duracion de reinado:

# %%
df['length of reign']= abs(df['Reign End'].astype(int) -df['Reign Start'].astype(int))

# %%
df.set_index('Index',inplace=True)

# %%
age_list=[]

for x,y in zip(df['Death'], df['Birth']):
    if pd.isna(x) or pd.isna(y):
        age =np.nan
    else:
        if int(x)<=int(y): 
            age = abs(int(x)+int(y))
        else:
            age = abs(int(x)-int(y))    
    age_list.append(age)
df['Age']=age_list

# %%
df.head(20)
# Out:
#                   Name                                          Full Name  \
# Index
# 1             Augustus              IMPERATOR CAESAR DIVI FILIVS AVGVSTVS
# 2             Tiberius       TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS
# 3             Caligula            GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS
# 4             Claudius       TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 5                 Nero           NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 6                Galba            SERVIVS SVLPICIVS GALBA CAESAR AVGVSTVS
# 7                 Otho                MARCVS SALVIVS OTHO CAESAR AVGVSTVS
# 8            Vitellius                AVLVS VITELLIVS GERMANICVS AVGVSTVS
# 9            Vespasian          TITVS FLAVIVS CAESAR VESPASIANVS AVGVSTVS
# 10               Titus          TITVS FLAVIVS CAESAR VESPASIANVS AVGVSTVS
# 11            Domitian           TITVS FLAVIVS CAESAR DOMITIANVS AVGVSTVS
# 12               Nerva              MARCVS COCCEIVS NERVA CAESAR AVGVSTVS
# ...

# %% [markdown]
# # Exploratory Data Analisys (EDA)

# %% [markdown]
# ### Causa de la muerte

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68 entries, 1 to 68
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             68 non-null     object
#  1   Full Name        68 non-null     object
#  2   Birth            64 non-null     object
#  3   Death            68 non-null     object
#  4   Birth City       61 non-null     object
#  5   Birth Province   68 non-null     object
#  6   Succession       68 non-null     object
#  7   Reign Start      68 non-null     object
#  8   Reign End        68 non-null     object
#  9   Cause            68 non-null     object
#  10  Killer           68 non-null     object
#  11  Dynasty          68 non-null     object
#  12  Era              68 non-null     object
#  13  length of reign  68 non-null     int32
#  14  Age              64 non-null     float64
# dtypes: float64(1), int32(1), object(13)
# memory usage: 8.2+ KB

# %%
def graf_cat(cat):
    # Calculamos el número de filas que necesitamos
    filas = ceil(cat.shape[1] / 2)

    # Definimos el gráfico
    f, ax = plt.subplots(nrows=filas, ncols=2, figsize=(16, filas * 6))

    # Aplanamos para iterar por el gráfico como si fuera de 1 dimensión en lugar de 2
    ax = ax.flat

    # Creamos el bucle que va añadiendo gráficos
    for cada, variable in enumerate(cat):
        order = cat[variable].value_counts().index
        sns.countplot(y=variable, data=cat, ax=ax[cada], palette='viridis',order=order)
        ax[cada].set_title(variable, fontsize=12, fontweight="bold")
        ax[cada].tick_params(labelsize=12)

    plt.tight_layout()  # Ajustamos el espacio entre los gráficos
    plt.show()

# %%
categorias = df[['Birth Province','Succession','Cause','Killer']]
graf_cat(categorias)

# %% [markdown]
# ### Media de la edad de los emperadores

# %%
df['Age'].mean()
# Out:
# 49.75

# %% [markdown]
# ### Media de la edad de reinado

# %%
df['length of reign'].mean()
# Out:
# 7.911764705882353

# %% [markdown]
# ### ¿Qué Era y Dinastía fue la peor, en términos de peligro para los emperadores?

# %%
df['Era'].value_counts()
# Out:
# Principate    48
# Dominate      20
# Name: Era, dtype: int64

# %%
df['Dynasty'].value_counts()
# Out:
# Gordian           22
# Constantinian     15
# Severan            8
# Nerva-Antonine     7
# Flavian            6
# Julio-Claudian     5
# Valentinian        4
# Theodosian         1
# Name: Dynasty, dtype: int64

# %%
prin=df[df['Era']=='Principate']['length of reign'].mean()

# %%
dom=df[df['Era']=='Dominate']['length of reign'].mean()

# %%
dinastias = dict(df.groupby('Dynasty')['length of reign'].mean())

dinasty_dict = dict(sorted(dinastias.items(), key=lambda x: x[1]))

# %%
fig, axs = plt.subplots(1, 2, figsize=(13, 5))

# Gráfico 1
era_unique = df['Era'].unique()
era_duration = [prin, dom]
sns.barplot(x=era_unique, y=era_duration, ax=axs[0], palette='viridis')
axs[0].set_title('Comparación de edad media de reinado por Era', fontweight='bold')
axs[0].set_xlabel('Era', fontweight='bold')
axs[0].set_ylabel('Duración media', fontweight='bold')

# Gráfico 2
sns.barplot(x=list(dinasty_dict.keys()), y=list(dinasty_dict.values()), ax=axs[1], palette='viridis')
axs[1].set_title('Comparación de edad media de reinado por dinastias', fontweight='bold')
axs[1].set_xlabel('Dinastia', fontweight='bold')
axs[1].set_xticklabels(dinasty_dict.keys(), rotation=45)
axs[1].set_ylabel('Duración media', fontweight='bold')

plt.subplots_adjust(wspace=0.5)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

grupo_killer_counts = df.groupby(['Era', 'Killer']).size().reset_index(name='Count')

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

#Principate
principate_data = grupo_killer_counts[grupo_killer_counts['Era'] == 'Principate']
axs[0].pie(principate_data['Count'], labels=principate_data['Killer'], autopct='%1.1f%%', startangle=90, pctdistance=0.85, colors=sns.color_palette('pastel'))
axs[0].set_title('Principate')

#Dominate
dominate_data = grupo_killer_counts[grupo_killer_counts['Era'] == 'Dominate']
axs[1].pie(dominate_data['Count'], labels=dominate_data['Killer'], autopct='%1.1f%%', startangle=90, pctdistance=0.85, colors=sns.color_palette('pastel'))
axs[1].set_title('Dominate')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

grupo_killer_counts = df.groupby(['Era', 'Cause']).size().reset_index(name='Count')

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

#Principate
principate_data = grupo_killer_counts[grupo_killer_counts['Era'] == 'Principate']
axs[0].pie(principate_data['Count'], labels=principate_data['Cause'], autopct='%1.1f%%', startangle=90, pctdistance=0.85, colors=sns.color_palette('pastel'))
axs[0].set_title('Principate')

#Dominate
dominate_data = grupo_killer_counts[grupo_killer_counts['Era'] == 'Dominate']
axs[1].pie(dominate_data['Count'], labels=dominate_data['Cause'], autopct='%1.1f%%', startangle=90, pctdistance=0.85, colors=sns.color_palette('pastel'))
axs[1].set_title('Dominate')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusiones:
#
# - La mayor parte de los emperadores romanos provienen de la peninsula itálica, seguido de la zona superior de los balcanes (la actual Bulgaria, Serbia..)
# - La principal causa de muerte de los emperadores era el asesinato (para el periodo Principate), seguido de causas naturales como enfermedades o vejez (para el periodo Dominate).
# - Cabe destacar que el principal causante de la muerte del emperador era otro emperador, seguido de enfermedades. En este apartado tienen importancia tanto la guardia pretoriana (que era la guardia personal del emperador) como el propio ejercito. En el caso de la era Principate, el emperador debía desconfiar tanto del ejército enemigo como del suyo propio, pues tenian las mismas posibilidades de causarle la muerte.
# - La edad media de reinado sube drasticamente al alcanzar la era Dominate, por lo que visto todo lo anterior se puede afirmar que el periodo Principate fue un periodo peligroso para ser emperador romano, ya que casi la mitad de las ocasiones morian asesinados. A la entrada del periodo Dominate, la decadencia romana era evidente, pero sin embargo, se volvió una epoca mas segura para los dirigentes, ya que la gran mayoria de veces morian por enfermedad.
