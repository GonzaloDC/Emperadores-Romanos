# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('roman-emperors.csv')

# %%
df.head()
# Out:
#    Index                Name  \
# 0     52            Galerius
# 1     57            Lucinius
# 2     33            Philip I
# 3     36  Trebonianus Gallus
# 4     31            Balbinus
#
#                                            Full Name  \
# 0       CAESAR GALERIVS VALERIVS MAXIMIANVS AVGVSTVS
# 1            CAESAR GAIVS VALERIVS LICINIVS AVGVSTVS
# 2            CAESAR MARCVS IVLIVS PHILIPPVS AVGVSTVS
# 3    CAESAR GAIVS VIBIVS TREBONIANVS GALLVS AVGVSTVS
# 4  CAESAR DECIMVS CAELIVS CALVINVS BALBINVS PIVS ...
#
#                        Birth                      Death       Birth City  \
# 0  0260-01-01T00:53:28+00:53  0311-05-01T00:53:28+00:53        Romuliana
# 1  0250-01-01T00:53:28+00:53  0325-03-01T00:53:28+00:53  Felix Romuliana
# 2  0204-01-01T00:53:28+00:53  0249-10-01T00:53:28+00:53           Shahba
# 3  0206-01-01T00:53:28+00:53  0253-08-15T00:53:28+00:53              NaN
# 4  0178-01-01T00:53:28+00:53  0238-07-29T00:53:28+00:53              NaN
#
#     Birth Province              Succession                Reign Start  \
# 0  Moesia Superior  Appointment by Emperor  0305-05-01T00:53:28+00:53
# 1  Moesia Superior              Birthright  0308-11-11T00:53:28+00:53
# 2            Syria            Seized Power  0244-02-14T00:53:28+00:53
# 3           Italia     Appointment by Army  0251-06-15T00:53:28+00:53
# 4          Unknown   Appointment by Senate  0238-04-22T00:53:28+00:53
#
#                    Reign End           Cause            Killer        Dynasty  \
# 0  0311-05-01T00:53:28+00:53  Natural Causes           Disease  Constantinian
# 1  0324-09-18T00:53:28+00:53       Execution     Other Emperor  Constantinian
# 2  0249-10-01T00:53:28+00:53       Execution     Other Emperor        Gordian
# 3  0253-08-15T00:53:28+00:53   Assassination     Other Emperor        Gordian
# 4  0238-07-29T00:53:28+00:53   Assassination  Praetorian Guard        Gordian
#
#           Era                                              Notes Verif  \
# 0    Dominate              birth, death, reign.end are estimates   NaN
# 1    Dominate                   birth, death, are only estimates   NaN
# 2  Principate                         reign.end is only estimate   NaN
# 3  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 4  Principate                            birth is only estimate.   NaN
#
#                                                Image  Unnamed: 17  \
# 0  https://public.opendatasoft.com/api/datasets/1...          NaN
# 1  https://public.opendatasoft.com/api/datasets/1...          NaN
# 2  https://public.opendatasoft.com/api/datasets/1...          NaN
# 3  https://public.opendatasoft.com/api/datasets/1...          NaN
# 4  https://public.opendatasoft.com/api/datasets/1...          NaN
#
#    Unnamed: 18  Unnamed: 19
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %% [markdown]
# ### Lo primero será ordenar los distintos emperadores por su indice, es decir, por orden cronológico en el que gobernaron:

# %%
df.sort_values(by='Index', inplace=True)

# %%
df.head()
# Out:
#     Index      Name                                     Full Name  \
# 15      1  Augustus         IMPERATOR CAESAR DIVI FILIVS AVGVSTVS
# 8       2  Tiberius  TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS
# 58      3  Caligula       GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS
# 53      4  Claudius  TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 50      5      Nero      NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS
#
#                         Birth                      Death Birth City  \
# 15  0062-09-23T00:53:28+00:53  0014-08-19T00:53:28+00:53       Rome
# 8   0041-11-16T00:53:28+00:53  0037-03-16T00:53:28+00:53       Rome
# 58  0012-08-31T00:53:28+00:53  0041-01-24T00:53:28+00:53    Antitum
# 53  0009-08-01T00:53:28+00:53  0054-10-13T00:53:28+00:53   Lugdunum
# 50  0037-12-15T00:53:28+00:53  0068-06-09T00:53:28+00:53    Antitum
#
#         Birth Province  Succession                Reign Start  \
# 15              Italia  Birthright  0026-01-16T00:53:28+00:53
# 8               Italia  Birthright  0014-09-18T00:53:28+00:53
# 58              Italia  Birthright  0037-03-18T00:53:28+00:53
# 53  Gallia Lugdunensis  Birthright  0041-01-25T00:53:28+00:53
# 50              Italia  Birthright  0054-10-13T00:53:28+00:53
#
#                     Reign End          Cause         Killer         Dynasty  \
# 15  0014-08-19T00:53:28+00:53  Assassination           Wife  Julio-Claudian
# 8   0037-03-16T00:53:28+00:53  Assassination  Other Emperor  Julio-Claudian
# 58  0041-01-24T00:53:28+00:53  Assassination         Senate  Julio-Claudian
# 53  0054-10-13T00:53:28+00:53  Assassination           Wife  Julio-Claudian
# 50  0068-06-09T00:53:28+00:53        Suicide         Senate  Julio-Claudian
#
#            Era                                              Notes Verif  \
# 15  Principate  birth, reign.start are BCE. Assign negative fo...   NaN
# 8   Principate  birth is BCE. Assign negative for correct ISO ...   NaN
# 58  Principate                                                NaN   NaN
# 53  Principate  birth is BCE. Assign negative for correct ISO ...   NaN
# 50  Principate                                                NaN   NaN
#
#                                                 Image  Unnamed: 17  \
# 15  https://public.opendatasoft.com/api/datasets/1...          NaN
# 8   https://public.opendatasoft.com/api/datasets/1...          NaN
# 58  https://public.opendatasoft.com/api/datasets/1...          NaN
# 53  https://public.opendatasoft.com/api/datasets/1...          NaN
# 50  https://public.opendatasoft.com/api/datasets/1...          NaN
#
#     Unnamed: 18  Unnamed: 19
# 15          NaN          NaN
# 8           NaN          NaN
# 58          NaN          NaN
# 53          NaN          NaN
# 50          NaN          NaN

# %% [markdown]
# ### Los siguientes pasos para organizar el dataframe serán:
# 1.Obtener sólo los años en las columnas de fechas.
#
# 2.intentar rellenar las columnas de Birth City y Birth Province
#
# 3.Eliminar las columnas que no nos interesan

# %%
df.isna().sum()
# Out:
# Index              0
# Name               0
# Full Name          0
# Birth              5
# Death              0
# Birth City        17
# Birth Province     0
# Succession         0
# Reign Start        0
# Reign End          0
# Cause              0
# Killer             0
# Dynasty            0
# Era                0
# Notes             23
# Verif             63
# Image              0
# Unnamed: 17       68
# Unnamed: 18       68
# Unnamed: 19       68
# dtype: int64

# %% [markdown]
# ### Se van a formatear las columnas de las fechas para obtener sólo los años. Se hará en las columnas <i>"Birth"</i> , <i>"Death"</i>, <i>"Reign Start"</i> y <i>"Reign End"</i>

# %%
df['Birth'] = df['Birth'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])
df['Death'] = df['Death'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])
df['Reign Start'] = df['Reign Start'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])
df['Reign End'] = df['Reign End'].apply(lambda x: np.nan if pd.isnull(x) else x.split('-')[0])

# %%
df[10:50]
# Out:
#     Index                Name  \
# 24     11            Domitian
# 57     12               Nerva
# 45     13              Trajan
# 44     14             Hadrian
# 56     15       Antonius Pius
# 23     16     Marcus Aurelius
# 54     17        Lucius Verus
# 42     18            Commodus
# 43     19            Pertinax
# 10     20     Didius Julianus
# 55     21    Septimus Severus
# 28     22           Caracalla
# 11     23                Geta
# 47     24            Macrinus
# 19     25          Elagabalus
# 35     26   Severus Alexander
# 20     27         Maximinus I
# 22     28           Gordian I
# 32     29          Gordian II
# 33     30            Pupienus
# 4      31            Balbinus
# 66     32         Gordian III
# 2      33            Philip I
# 16     34       Trajan Decius
# 27     35           Hostilian
# 3      36  Trebonianus Gallus
# 63     37            Aemilian
# 62     38            Valerian
# 21     39           Gallienus
# 29     40   Claudius Gothicus
# 48     41          Quintillus
# 5      42            Aurelian
# 17     43             Tacitus
# 49     44             Florian
# 18     45              Probus
# 12     46               Carus
# 6      47            Numerian
# 7      48             Carinus
# 36     49          Diocletian
# 61     50            Maximian
#
#                                             Full Name Birth Death  \
# 24           TITVS FLAVIVS CAESAR DOMITIANVS AVGVSTVS  0051  0096
# 57              MARCVS COCCEIVS NERVA CAESAR AVGVSTVS  0030  0098
# 45       CAESAR MARCVS VLPIVS NERVA TRAIANVS AVGVSTVS  0053  0117
# 44  CAESAR PVBLIVS AELIVS TRAIANVS HADRIANVS AVGVSTVS  0076  0138
# 56  CAESAR TITVS AELIVS HADRIANVS ANTONINVS AVGVST...  0086  0161
# 23          CAESAR MARCVS AVRELIVS ANTONINVS AVGVSTVS  0121  0180
# 54              CAESAR LVCIVS AVRELIVS VERVS AVGVSTVS  0130  0169
# 42  CAESAR MARCVS AVRELIVS COMMODVS ANTONINVS AVGV...  0161  0192
# 43           CAESAR PVBLIVS HELVIVS PERTINAX AVGVSTVS  0126  0193
# 10     CAESAR MARCVS DIDIVS SEVERVS IVLIANVS AVGVSTVS  0133  0193
# 55  CAESAR LVCIVS SEPTIMIVS SEVERVS PERTINAX AVGVSTVS  0145  0211
# 28  CAESAR MARCVS AVRELIVS SEVERVS ANTONINVS PIVS ...  0188  0217
# 11             CAESAR PVBLIVS SEPTIMIVS GETA AVGVSTUS  0189  0211
# 47  MARCVS OPELLIVS SEVERVS MACRINVS AVGVSTVS PIVS...  0165  0218
# 19                 MARCVS AVRELIVS ANTONINVS AVGVSTVS  0203  0222
# 35  CAESAR MARCVS AVRELIVS SEVERVS ALEXANDER AVGVSTVS  0208  0235
# 20       CAESAR GAIVS IVLIVS VERVS MAXIMINVS AVGVSTVS  0173  0238
# 22  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0159  0238
# 32  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0192  0238
# 33    CAESAR MARCVS CLODIVS PVPIENVS MAXIMVS AVGVSTVS  0178  0238
# 4   CAESAR DECIMVS CAELIVS CALVINVS BALBINVS PIVS ...  0178  0238
# 66          CAESAR MARCVS ANTONIVS GORDIANVS AVGVSTVS  0225  0244
# 2             CAESAR MARCVS IVLIVS PHILIPPVS AVGVSTVS  0204  0249
# 16  CAESAR GAIVS MESSIVS QVINTVS TRAIANVS DECIVS A...  0201  0251
# 27  CAESAR CAIVS VALENS HOSTILIANVS MESSIVS QVINTV...  0230  0251
# 3     CAESAR GAIVS VIBIVS TREBONIANVS GALLVS AVGVSTVS  0206  0253
# 63         CAESAR MARCVS AEMILIVS AEMILIANVS AVGVSTVS  0207  0253
# 62        CAESAR PVBLIVS LICINIVS VALERIANVS AVGVSTVS  0195  0264
# 21  CAESAR PVBLIVS LICINIVS EGNATIVS GALLIENVS AVG...  0218  0268
# 29           CAESAR MARCVS AVRELIVS CLAVDIVS AVGVSTVS  0213  0270
# 48  CAESAR MARCVS AVRELIVS CLAVDIVS QVINTILLVS AVG...  0212  0270
# 5          CAESAR LVCIVS DOMITIVS AVRELIANVS AVGVSTVS  0214  0275
# 17            CAESAR MARCVS CLAVDIVS TACITVS AVGVSTVS  0200  0276
# 49            CAESAR MARCVS ANNIVS FLORIANVS AVGVSTVS   NaN  0276
# 18             CAESAR MARCVS AVRELIVS PROBVS AVGVSTVS  0232  0282
# 12              CAESAR MARCVS AVRELIVS CARVS AVGVSTVS  0230  0283
# 6   CAESAR MARCVS AVRELIVS NVMERIVS NVMERIANVS AVG...   NaN  0284
# 7             CAESAR MARCVS AVRELIVS CARINVS AVGVSTVS   NaN  0285
# 36  CAESAR GAIVS AVRELIVS VALERIVS DIOCLETIANVS AV...  0244  0311
# 61  CAESAR MARCVS AVRELIVS VALERIVS MAXIMIANVS AVG...  0250  0310
#
#           Birth City      Birth Province                       Succession  \
# 24              Rome              Italia                       Birthright
# 57             Narni              Italia            Appointment by Senate
# 45           Italica    Hispania Baetica                       Birthright
# 44           Italica    Hispania Baetica                       Birthright
# 56          Lanuvium              Italia                       Birthright
# 23              Rome              Italia                       Birthright
# 54              Rome              Italia                       Birthright
# 42          Lanuvium              Italia                       Birthright
# 43              Alba              Italia  Appointment by Praetorian Guard
# 10             Milan              Italia                         Purchase
# 55      Leptis Magna               Libya                     Seized Power
# 28          Lugdunum  Gallia Lugdunensis                       Birthright
# 11              Rome              Italia                       Birthright
# 47      Iol Caesarea          Mauretania                     Seized Power
# 19             Emesa               Syria                       Birthright
# 35     Arca Caesarea               Syria                       Birthright
# 20               NaN              Thrace  Appointment by Praetorian Guard
# 22               NaN             Phrygia            Appointment by Senate
# 32               NaN             Unknown            Appointment by Senate
# 33               NaN             Unknown            Appointment by Senate
# 4                NaN             Unknown            Appointment by Senate
# 66              Rome              Italia            Appointment by Senate
# 2             Shahba               Syria                     Seized Power
# 16           Budalia   Pannonia Inferior              Appointment by Army
# 27           Sirmium            Pannonia                       Birthright
# 3                NaN              Italia              Appointment by Army
# 63               NaN              Africa              Appointment by Army
# 62               NaN             Unknown              Appointment by Army
# 21               NaN             Unknown                       Birthright
# 29           Sirmium            Pannonia                     Seized Power
# 48           Sirmium            Pannonia                       Birthright
# 5            Sirmium            Pannonia              Appointment by Army
# 17  Interamna Nahars              Italia            Appointment by Senate
# 49               NaN             Unknown                       Birthright
# 18           Sirmium            Pannonia              Appointment by Army
# 12             Narbo  Gallia Narbonensis                     Seized Power
# 6                NaN             Unknown                       Birthright
# 7                NaN             Unknown                       Birthright
# 36            Salona           Dalmatian                     Seized Power
# 61           Sirmium            Pannonia           Appointment by Emperor
#
#    Reign Start Reign End           Cause            Killer         Dynasty  \
# 24        0081      0096   Assassination   Court Officials         Flavian
# 57        0096      0098  Natural Causes           Disease  Nerva-Antonine
# 45        0098      0117  Natural Causes           Disease  Nerva-Antonine
# 44        0117      0138  Natural Causes     Heart Failure  Nerva-Antonine
# 56        0138      0161  Natural Causes           Disease  Nerva-Antonine
# 23        0161      0180  Natural Causes           Disease  Nerva-Antonine
# 54        0161      0169  Natural Causes           Disease  Nerva-Antonine
# 42        0177      0192   Assassination  Praetorian Guard  Nerva-Antonine
# 43        0193      0193   Assassination  Praetorian Guard         Severan
# 10        0193      0193       Execution            Senate         Severan
# 55        0193      0211  Natural Causes           Disease         Severan
# 28        0198      0217   Assassination     Other Emperor         Severan
# 11        0209      0211   Assassination     Other Emperor         Severan
# 47        0217      0218       Execution     Other Emperor         Severan
# 19        0218      0222   Assassination  Praetorian Guard         Severan
# 35        0222      0235   Assassination          Own Army         Severan
# 20        0235      0238   Assassination  Praetorian Guard         Gordian
# 22        0238      0238         Suicide     Other Emperor         Gordian
# 32        0238      0238       Execution     Other Emperor         Gordian
# 33        0238      0238   Assassination  Praetorian Guard         Gordian
# 4         0238      0238   Assassination  Praetorian Guard         Gordian
# 66        0238      0244  Died in Battle     Opposing Army         Gordian
# 2         0244      0249       Execution     Other Emperor         Gordian
# 16        0249      0251  Died in Battle     Opposing Army         Gordian
# 27        0251      0251  Natural Causes           Disease         Gordian
# 3         0251      0253   Assassination     Other Emperor         Gordian
# 63        0253      0253   Assassination     Other Emperor         Gordian
# 62        0253      0260       Captivity     Opposing Army         Gordian
# 21        0253      0268   Assassination          Own Army         Gordian
# 29        0268      0270  Natural Causes           Disease         Gordian
# 48        0270      0270         Unknown           Unknown         Gordian
# 5         0270      0275   Assassination  Praetorian Guard         Gordian
# 17        0275      0276  Natural Causes           Disease         Gordian
# 49        0276      0276   Assassination          Own Army         Gordian
# 18        0276      0282   Assassination          Own Army         Gordian
# 12        0282      0283  Natural Causes         Lightning         Gordian
# 6         0283      0284         Unknown           Unknown         Gordian
# 7         0283      0285  Died in Battle     Opposing Army         Gordian
# 36        0284      0305  Natural Causes           Disease   Constantinian
# 61        0286      0305         Suicide     Other Emperor   Constantinian
#
#            Era                                              Notes Verif  \
# 24  Principate                                                NaN   NaN
# 57  Principate                                                NaN   NaN
# 45  Principate                                                NaN   NaN
# 44  Principate                                                NaN   NaN
# 56  Principate                                                NaN   NaN
# 23  Principate                                                NaN   NaN
# 54  Principate                     death, reign.end are estimates   NaN
# 42  Principate                 reign.start is only valid for year   NaN
# 43  Principate                                                NaN   NaN
# 10  Principate                     birth could also be 0137-02-02   NaN
# 55  Principate                                                NaN   NaN
# 28  Principate                 reign.start is only valid for year   NaN
# 11  Principate                 reign.start is only valid for year   NaN
# 47  Principate                       birth is only valid for year   NaN
# 19  Principate                             birth is only estimate   NaN
# 35  Principate                                                NaN   NaN
# 20  Principate  birth is only estimate. Death, reign.end are e...   NaN
# 22  Principate                            birth is only estimate.   NaN
# 32  Principate                            birth is only estimate.   NaN
# 33  Principate                            birth is only estimate.   NaN
# 4   Principate                            birth is only estimate.   NaN
# 66  Principate                                                NaN   NaN
# 2   Principate                         reign.end is only estimate   NaN
# 16  Principate  birth is only estimate. Reign.end is only esti...   NaN
# 27  Principate  birth is only estimate. Reign.end is only esti...   NaN
# 3   Principate  birth, death, reign.end, reign.start are estim...   NaN
# 63  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 62  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 21  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 29  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 48  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 5   Principate                                                NaN   NaN
# 17  Principate             birth, death, reign.end are estimates.   NaN
# 49  Principate  death, reign.end, reign.start are estimates. B...   NaN
# 18  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 12  Principate  birth, death, reign.end, reign.start are estim...   NaN
# 6   Principate  death, reign.end, reign.start are estimates. B...   NaN
# 7   Principate  death, reign.end, reign.start are estimates. B...   NaN
# 36    Dominate                                                NaN   NaN
# 61    Dominate                         birth, death are estimates   NaN
#
#                                                 Image  Unnamed: 17  \
# 24  https://public.opendatasoft.com/api/datasets/1...          NaN
# 57  https://public.opendatasoft.com/api/datasets/1...          NaN
# 45  https://public.opendatasoft.com/api/datasets/1...          NaN
# 44  https://public.opendatasoft.com/api/datasets/1...          NaN
# 56  https://public.opendatasoft.com/api/datasets/1...          NaN
# 23  https://public.opendatasoft.com/api/datasets/1...          NaN
# 54  https://public.opendatasoft.com/api/datasets/1...          NaN
# 42  https://public.opendatasoft.com/api/datasets/1...          NaN
# 43  https://public.opendatasoft.com/api/datasets/1...          NaN
# 10  https://public.opendatasoft.com/api/datasets/1...          NaN
# 55  https://public.opendatasoft.com/api/datasets/1...          NaN
# 28  https://public.opendatasoft.com/api/datasets/1...          NaN
# 11  https://public.opendatasoft.com/api/datasets/1...          NaN
# 47  https://public.opendatasoft.com/api/datasets/1...          NaN
# 19  https://public.opendatasoft.com/api/datasets/1...          NaN
# 35  https://public.opendatasoft.com/api/datasets/1...          NaN
# 20  https://public.opendatasoft.com/api/datasets/1...          NaN
# 22  https://public.opendatasoft.com/api/datasets/1...          NaN
# 32  https://public.opendatasoft.com/api/datasets/1...          NaN
# 33  https://public.opendatasoft.com/api/datasets/1...          NaN
# 4   https://public.opendatasoft.com/api/datasets/1...          NaN
# 66  https://public.opendatasoft.com/api/datasets/1...          NaN
# 2   https://public.opendatasoft.com/api/datasets/1...          NaN
# 16  https://public.opendatasoft.com/api/datasets/1...          NaN
# 27  https://public.opendatasoft.com/api/datasets/1...          NaN
# 3   https://public.opendatasoft.com/api/datasets/1...          NaN
# 63  https://public.opendatasoft.com/api/datasets/1...          NaN
# 62  https://public.opendatasoft.com/api/datasets/1...          NaN
# 21  https://public.opendatasoft.com/api/datasets/1...          NaN
# 29  https://public.opendatasoft.com/api/datasets/1...          NaN
# 48  https://public.opendatasoft.com/api/datasets/1...          NaN
# 5   https://public.opendatasoft.com/api/datasets/1...          NaN
# 17  https://public.opendatasoft.com/api/datasets/1...          NaN
# 49  https://public.opendatasoft.com/api/datasets/1...          NaN
# 18  https://public.opendatasoft.com/api/datasets/1...          NaN
# 12  https://public.opendatasoft.com/api/datasets/1...          NaN
# 6   https://public.opendatasoft.com/api/datasets/1...          NaN
# 7   https://public.opendatasoft.com/api/datasets/1...          NaN
# 36  https://public.opendatasoft.com/api/datasets/1...          NaN
# 61  https://public.opendatasoft.com/api/datasets/1...          NaN
#
#     Unnamed: 18  Unnamed: 19
# 24          NaN          NaN
# 57          NaN          NaN
# 45          NaN          NaN
# 44          NaN          NaN
# 56          NaN          NaN
# 23          NaN          NaN
# 54          NaN          NaN
# 42          NaN          NaN
# 43          NaN          NaN
# 10          NaN          NaN
# 55          NaN          NaN
# 28          NaN          NaN
# 11          NaN          NaN
# 47          NaN          NaN
# 19          NaN          NaN
# 35          NaN          NaN
# 20          NaN          NaN
# 22          NaN          NaN
# 32          NaN          NaN
# 33          NaN          NaN
# 4           NaN          NaN
# 66          NaN          NaN
# 2           NaN          NaN
# 16          NaN          NaN
# 27          NaN          NaN
# 3           NaN          NaN
# 63          NaN          NaN
# 62          NaN          NaN
# 21          NaN          NaN
# 29          NaN          NaN
# 48          NaN          NaN
# 5           NaN          NaN
# 17          NaN          NaN
# 49          NaN          NaN
# 18          NaN          NaN
# 12          NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 36          NaN          NaN
# 61          NaN          NaN

# %% [markdown]
# ### El siguiente paso sera rellenar las columnas (si es posible) <i>"Birth City"</i> y <i>"Birth Province"</i> en caso de que tengan valores nulos o valores unknown.

# %%
df.isna().sum()
# Out:
# Index              0
# Name               0
# Full Name          0
# Birth              5
# Death              0
# Birth City        17
# Birth Province     0
# Succession         0
# Reign Start        0
# Reign End          0
# Cause              0
# Killer             0
# Dynasty            0
# Era                0
# Notes             23
# Verif             63
# Image              0
# Unnamed: 17       68
# Unnamed: 18       68
# Unnamed: 19       68
# dtype: int64

# %%
df[df['Birth City'].isna()]
# Out:
#     Index                Name  \
# 20     27         Maximinus I
# 22     28           Gordian I
# 32     29          Gordian II
# 33     30            Pupienus
# 4      31            Balbinus
# 3      36  Trebonianus Gallus
# 63     37            Aemilian
# 62     38            Valerian
# 21     39           Gallienus
# 49     44             Florian
# 6      47            Numerian
# 7      48             Carinus
# 52     53          Severus II
# 65     55           Maxentius
# 64     56        Maximinus II
# 14     60            Constans
# 51     61            Vetranio
#
#                                             Full Name Birth Death Birth City  \
# 20       CAESAR GAIVS IVLIVS VERVS MAXIMINVS AVGVSTVS  0173  0238        NaN
# 22  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0159  0238        NaN
# 32  CAESAR MARCVS ANTONIVS GORDIANVS SEMPRONIANVS ...  0192  0238        NaN
# 33    CAESAR MARCVS CLODIVS PVPIENVS MAXIMVS AVGVSTVS  0178  0238        NaN
# 4   CAESAR DECIMVS CAELIVS CALVINVS BALBINVS PIVS ...  0178  0238        NaN
# 3     CAESAR GAIVS VIBIVS TREBONIANVS GALLVS AVGVSTVS  0206  0253        NaN
# 63         CAESAR MARCVS AEMILIVS AEMILIANVS AVGVSTVS  0207  0253        NaN
# 62        CAESAR PVBLIVS LICINIVS VALERIANVS AVGVSTVS  0195  0264        NaN
# 21  CAESAR PVBLIVS LICINIVS EGNATIVS GALLIENVS AVG...  0218  0268        NaN
# 49            CAESAR MARCVS ANNIVS FLORIANVS AVGVSTVS   NaN  0276        NaN
# 6   CAESAR MARCVS AVRELIVS NVMERIVS NVMERIANVS AVG...   NaN  0284        NaN
# 7             CAESAR MARCVS AVRELIVS CARINVS AVGVSTVS   NaN  0285        NaN
# 52                  FLAVIVS VALERIVS SEVERVS AVGVSTVS   NaN  0307        NaN
# 65        MARCVS AVRELIVS VALERIVS MAXENTIVS AVGVSTVS  0278  0312        NaN
# 64        CAESAR GALERIVS VALERIVS MAXIMINVS AVGVSTVS  0270  0313        NaN
# 14            CAESAR FLAVIVS IVLIVS CONSTANS AVGVSTVS  0320  0350        NaN
# 51                   CAESAR FLAVIVS VETRANIO AVGVSTVS   NaN  0356        NaN
#
#      Birth Province                       Succession Reign Start Reign End  \
# 20           Thrace  Appointment by Praetorian Guard        0235      0238
# 22          Phrygia            Appointment by Senate        0238      0238
# 32          Unknown            Appointment by Senate        0238      0238
# 33          Unknown            Appointment by Senate        0238      0238
# 4           Unknown            Appointment by Senate        0238      0238
# 3            Italia              Appointment by Army        0251      0253
# 63           Africa              Appointment by Army        0253      0253
# 62          Unknown              Appointment by Army        0253      0260
# 21          Unknown                       Birthright        0253      0268
# 49          Unknown                       Birthright        0276      0276
# 6           Unknown                       Birthright        0283      0284
# 7           Unknown                       Birthright        0283      0285
# 52          Unknown           Appointment by Emperor        0305      0307
# 65          Unknown                       Birthright        0306      0312
# 64  Dacia Aureliana                       Birthright        0311      0313
# 14           Moesia                       Birthright        0337      0350
# 51           Moesia                     Seized Power        0350      0350
#
#              Cause            Killer        Dynasty         Era  \
# 20   Assassination  Praetorian Guard        Gordian  Principate
# 22         Suicide     Other Emperor        Gordian  Principate
# 32       Execution     Other Emperor        Gordian  Principate
# 33   Assassination  Praetorian Guard        Gordian  Principate
# 4    Assassination  Praetorian Guard        Gordian  Principate
# 3    Assassination     Other Emperor        Gordian  Principate
# 63   Assassination     Other Emperor        Gordian  Principate
# 62       Captivity     Opposing Army        Gordian  Principate
# 21   Assassination          Own Army        Gordian  Principate
# 49   Assassination          Own Army        Gordian  Principate
# 6          Unknown           Unknown        Gordian  Principate
# 7   Died in Battle     Opposing Army        Gordian  Principate
# 52   Assassination     Other Emperor  Constantinian    Dominate
# 65       Execution     Other Emperor  Constantinian    Dominate
# 64       Execution     Other Emperor  Constantinian    Dominate
# 14   Assassination           Usurper  Constantinian    Dominate
# 51         Unknown           Unknown  Constantinian    Dominate
#
#                                                 Notes Verif  \
# 20  birth is only estimate. Death, reign.end are e...   NaN
# 22                            birth is only estimate.   NaN
# 32                            birth is only estimate.   NaN
# 33                            birth is only estimate.   NaN
# 4                             birth is only estimate.   NaN
# 3   birth, death, reign.end, reign.start are estim...   NaN
# 63  birth, death, reign.end, reign.start are estim...   NaN
# 62  birth, death, reign.end, reign.start are estim...   NaN
# 21  birth, death, reign.end, reign.start are estim...   NaN
# 49  death, reign.end, reign.start are estimates. B...   NaN
# 6   death, reign.end, reign.start are estimates. B...   NaN
# 7   death, reign.end, reign.start are estimates. B...   NaN
# 52                                                NaN   NaN
# 65                            birth is only estimate.   NaN
# 64                death, reign.end are only estimates   NaN
# 14  birth, death, reign.end, reign.start are estim...   NaN
# 51                             death is only estimate   NaN
#
#                                                 Image  Unnamed: 17  \
# 20  https://public.opendatasoft.com/api/datasets/1...          NaN
# 22  https://public.opendatasoft.com/api/datasets/1...          NaN
# 32  https://public.opendatasoft.com/api/datasets/1...          NaN
# 33  https://public.opendatasoft.com/api/datasets/1...          NaN
# 4   https://public.opendatasoft.com/api/datasets/1...          NaN
# 3   https://public.opendatasoft.com/api/datasets/1...          NaN
# 63  https://public.opendatasoft.com/api/datasets/1...          NaN
# 62  https://public.opendatasoft.com/api/datasets/1...          NaN
# 21  https://public.opendatasoft.com/api/datasets/1...          NaN
# 49  https://public.opendatasoft.com/api/datasets/1...          NaN
# 6   https://public.opendatasoft.com/api/datasets/1...          NaN
# 7   https://public.opendatasoft.com/api/datasets/1...          NaN
# 52  https://public.opendatasoft.com/api/datasets/1...          NaN
# 65  https://public.opendatasoft.com/api/datasets/1...          NaN
# 64  https://public.opendatasoft.com/api/datasets/1...          NaN
# 14  https://public.opendatasoft.com/api/datasets/1...          NaN
# 51  https://public.opendatasoft.com/api/datasets/1...          NaN
#
#     Unnamed: 18  Unnamed: 19
# 20          NaN          NaN
# 22          NaN          NaN
# 32          NaN          NaN
# 33          NaN          NaN
# 4           NaN          NaN
# 3           NaN          NaN
# 63          NaN          NaN
# 62          NaN          NaN
# 21          NaN          NaN
# 49          NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 52          NaN          NaN
# 65          NaN          NaN
# 64          NaN          NaN
# 14          NaN          NaN
# 51          NaN          NaN

# %% [markdown]
# ### De los 17 valores NaN de Birth City, se tienen 7 en los que si que se conoce el Birth Province, por lo que se tomará la capital de dicha provincia como aproximación.

# %%
df.at[51,'Birth']=310
df.at[31,'Birth Province']='Italia'

# %%
df[df['Birth Province']=='Moesia']=df[df['Birth Province']=='Moesia'].fillna('Dardania')
df[df['Birth Province']=='Phrygia']=df[df['Birth Province']=='Phrygia'].fillna('Phrygia')
df[df['Birth Province']=='Italia']=df[df['Birth Province']=='Italia'].fillna('Rome')
df[df['Birth Province']=='Africa']=df[df['Birth Province']=='Africa'].fillna('Djerba')
df[df['Birth Province']=='Dacia Aureliana']=df[df['Birth Province']=='Dacia Aureliana'].fillna('Dacia Aureliana')
df[df['Birth Province']=='Thrace']=df[df['Birth Province']=='Thrace'].fillna('Thrace')

# %% [markdown]
# ### De los 10 restantes, se ha procedido a buscar el origen y rellenarlo:

# %%
df.at[32,['Birth City','Birth Province']]='Phrygia' #Gordiano II
df.at[4,['Birth City','Birth Province']]='Rome' #Balbinus
df.at[49,'Birth City']='Terni' #florian
df.at[49,'Birth Province']='Italia' #Severus II
df.at[48,['Birth City','Birth Province']]='illyria' #Severus II

# %% [markdown]
# ### Lo siguiente sera eliminar las columnas que no necesitamos:
# - Notes
# - Verif
# - Image
# - Unnamed: 17
# - Unnamed: 18
# - Unnamed: 19

# %%
df.drop(['Notes','Verif','Image','Unnamed: 17','Unnamed: 18','Unnamed: 19'],axis=1, inplace=True)

# %%
df.head()
# Out:
#     Index      Name                                     Full Name Birth Death  \
# 15      1  Augustus         IMPERATOR CAESAR DIVI FILIVS AVGVSTVS  0062  0014
# 8       2  Tiberius  TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS  0041  0037
# 58      3  Caligula       GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS  0012  0041
# 53      4  Claudius  TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS  0009  0054
# 50      5      Nero      NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS  0037  0068
#
#    Birth City      Birth Province  Succession Reign Start Reign End  \
# 15       Rome              Italia  Birthright        0026      0014
# 8        Rome              Italia  Birthright        0014      0037
# 58    Antitum              Italia  Birthright        0037      0041
# 53   Lugdunum  Gallia Lugdunensis  Birthright        0041      0054
# 50    Antitum              Italia  Birthright        0054      0068
#
#             Cause         Killer         Dynasty         Era
# 15  Assassination           Wife  Julio-Claudian  Principate
# 8   Assassination  Other Emperor  Julio-Claudian  Principate
# 58  Assassination         Senate  Julio-Claudian  Principate
# 53  Assassination           Wife  Julio-Claudian  Principate
# 50        Suicide         Senate  Julio-Claudian  Principate

# %% [markdown]
# ### Agregaremos duracion de reinado:

# %%
df['length of reign']= abs(df['Reign End'].astype(int) -df['Reign Start'].astype(int))

# %%
df.set_index('Index',inplace=True)

# %%
age_list=[]

for x,y in zip(df['Death'], df['Birth']):
    if pd.isna(x) or pd.isna(y):
        age =np.nan
    else:
        if int(x)<=int(y): 
            age = abs(int(x)+int(y))
        else:
            age = abs(int(x)-int(y))    
    age_list.append(age)
df['Age']=age_list

# %%
df.head(20)
# Out:
#                   Name                                          Full Name  \
# Index
# 1             Augustus              IMPERATOR CAESAR DIVI FILIVS AVGVSTVS
# 2             Tiberius       TIBERIVS CAESAR DIVI AVGVSTI FILIVS AVGVSTVS
# 3             Caligula            GAIVS IVLIVS CAESAR AVGVSTVS GERMANICVS
# 4             Claudius       TIBERIVS CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 5                 Nero           NERO CLAVDIVS CAESAR AVGVSTVS GERMANICVS
# 6                Galba            SERVIVS SVLPICIVS GALBA CAESAR AVGVSTVS
# 7                 Otho                MARCVS SALVIVS OTHO CAESAR AVGVSTVS
# 8            Vitellius                AVLVS VITELLIVS GERMANICVS AVGVSTVS
# 9            Vespasian          TITVS FLAVIVS CAESAR VESPASIANVS AVGVSTVS
# 10               Titus          TITVS FLAVIVS CAESAR VESPASIANVS AVGVSTVS
# 11            Domitian           TITVS FLAVIVS CAESAR DOMITIANVS AVGVSTVS
# 12               Nerva              MARCVS COCCEIVS NERVA CAESAR AVGVSTVS
# 13              Trajan       CAESAR MARCVS VLPIVS NERVA TRAIANVS AVGVSTVS
# 14             Hadrian  CAESAR PVBLIVS AELIVS TRAIANVS HADRIANVS AVGVSTVS
# 15       Antonius Pius  CAESAR TITVS AELIVS HADRIANVS ANTONINVS AVGVST...
# 16     Marcus Aurelius          CAESAR MARCVS AVRELIVS ANTONINVS AVGVSTVS
# 17        Lucius Verus              CAESAR LVCIVS AVRELIVS VERVS AVGVSTVS
# 18            Commodus  CAESAR MARCVS AVRELIVS COMMODVS ANTONINVS AVGV...
# 19            Pertinax           CAESAR PVBLIVS HELVIVS PERTINAX AVGVSTVS
# 20     Didius Julianus     CAESAR MARCVS DIDIVS SEVERVS IVLIANVS AVGVSTVS
#
#       Birth Death  Birth City      Birth Province  \
# Index
# 1      0062  0014        Rome              Italia
# 2      0041  0037        Rome              Italia
# 3      0012  0041     Antitum              Italia
# 4      0009  0054    Lugdunum  Gallia Lugdunensis
# 5      0037  0068     Antitum              Italia
# 6      0002  0069   Terracina              Italia
# 7      0032  0069  Terentinum              Italia
# 8      0015  0069        Rome              Italia
# 9      0009  0079   Falacrine              Italia
# 10     0039  0081        Rome              Italia
# 11     0051  0096        Rome              Italia
# 12     0030  0098       Narni              Italia
# 13     0053  0117     Italica    Hispania Baetica
# 14     0076  0138     Italica    Hispania Baetica
# 15     0086  0161    Lanuvium              Italia
# 16     0121  0180        Rome              Italia
# 17     0130  0169        Rome              Italia
# 18     0161  0192    Lanuvium              Italia
# 19     0126  0193        Alba              Italia
# 20     0133  0193       Milan              Italia
#
#                             Succession Reign Start Reign End           Cause  \
# Index
# 1                           Birthright        0026      0014   Assassination
# 2                           Birthright        0014      0037   Assassination
# 3                           Birthright        0037      0041   Assassination
# 4                           Birthright        0041      0054   Assassination
# 5                           Birthright        0054      0068         Suicide
# 6                         Seized Power        0068      0069   Assassination
# 7      Appointment by Praetorian Guard        0069      0069         Suicide
# 8                         Seized Power        0069      0069   Assassination
# 9                         Seized Power        0069      0079  Natural Causes
# 10                          Birthright        0079      0081  Natural Causes
# 11                          Birthright        0081      0096   Assassination
# 12               Appointment by Senate        0096      0098  Natural Causes
# 13                          Birthright        0098      0117  Natural Causes
# 14                          Birthright        0117      0138  Natural Causes
# 15                          Birthright        0138      0161  Natural Causes
# 16                          Birthright        0161      0180  Natural Causes
# 17                          Birthright        0161      0169  Natural Causes
# 18                          Birthright        0177      0192   Assassination
# 19     Appointment by Praetorian Guard        0193      0193   Assassination
# 20                            Purchase        0193      0193       Execution
#
#                  Killer         Dynasty         Era  length of reign   Age
# Index
# 1                  Wife  Julio-Claudian  Principate               12  76.0
# 2         Other Emperor  Julio-Claudian  Principate               23  78.0
# 3                Senate  Julio-Claudian  Principate                4  29.0
# 4                  Wife  Julio-Claudian  Principate               13  45.0
# 5                Senate  Julio-Claudian  Principate               14  31.0
# 6         Other Emperor         Flavian  Principate                1  67.0
# 7         Other Emperor         Flavian  Principate                0  37.0
# 8         Other Emperor         Flavian  Principate                0  54.0
# 9               Disease         Flavian  Principate               10  70.0
# 10              Disease         Flavian  Principate                2  42.0
# 11      Court Officials         Flavian  Principate               15  45.0
# 12              Disease  Nerva-Antonine  Principate                2  68.0
# 13              Disease  Nerva-Antonine  Principate               19  64.0
# 14        Heart Failure  Nerva-Antonine  Principate               21  62.0
# 15              Disease  Nerva-Antonine  Principate               23  75.0
# 16              Disease  Nerva-Antonine  Principate               19  59.0
# 17              Disease  Nerva-Antonine  Principate                8  39.0
# 18     Praetorian Guard  Nerva-Antonine  Principate               15  31.0
# 19     Praetorian Guard         Severan  Principate                0  67.0
# 20               Senate         Severan  Principate                0  60.0

# %% [markdown]
# # Exploratory Data Analisys (EDA)

# %% [markdown]
# ### Causa de la muerte

# %%
df['Cause'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Provincia de la que solian venir

# %%
df['Birth Province'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Culpable de la muerte

# %%
df['Killer'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Media de la edad de los emperadores

# %%
df['Age'].mean()
# Out:
# 49.75

# %% [markdown]
# ### Media de la edad de reinado

# %%
df['length of reign'].mean()
# Out:
# 7.911764705882353

# %% [markdown]
# ### ¿Qué Era fue la peor, en términos de peligro para los emperadores?

# %%
df['Era'].unique()
# Out:
# array(['Principate', 'Dominate'], dtype=object)

# %%
n=4
r = np.arange(n)
width = 0.25
Women = [115, 215, 250, 200]
Men = [114, 230, 510, 370]


plt.bar(r, Women, color = 'b',
        width = width, edgecolor = 'black',
        label='Women')


plt.bar(r + width, Men, color = 'g',
        width = width, edgecolor = 'black',
        label='Men')


plt.xlabel("Year")
plt.ylabel("Number of people voted")
plt.title("Number of people voted in each year")
  
# plt.grid(linestyle='--')
plt.xticks(r + width/2,['2018','2019','2020','2021'])
plt.legend()
  
plt.show()

# %%
n=2
r = np.arange(n)
width = 0.25

Principate=df[df['Era']=='Principate']
Dominate=df[df['Era']=='Dominate']


plt.bar(r, Principate, color = 'b',
        width = width, edgecolor = 'black',
        label='Principate')


plt.bar(r + width, Dominate, color = 'g',
        width = width, edgecolor = 'black',
        label='Dominate')


plt.xlabel("Year")
plt.ylabel("Number of people voted")
plt.title("Number of people voted in each year")
  
# plt.grid(linestyle='--')
plt.xticks(r + width/2,df['Cause'])
plt.legend()
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 9>()
#       5 Principate=df[df['Era']=='Principate']
#       6 Dominate=df[df['Era']=='Dominate']
# ----> 9 plt.bar(r, Principate, color = 'b',
#      10         width = width, edgecolor = 'black',
#      11         label='Principate')
#      14 plt.bar(r + width, Dominate, color = 'g',
#      15         width = width, edgecolor = 'black',
#      16         label='Dominate')
#      19 plt.xlabel("Year")
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
#    2383 @_copy_docstring_and_deprecators(Axes.bar)
#    2384 def bar(
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:2317, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2314         x = 0
#    2316 if orientation == 'vertical':
# -> 2317     self._process_unit_info(
#    2318         [("x", x), ("y", height)], kwargs, convert=False)
#    2319     if log:
#    2320         self.set_yscale('log', nonpositive='clip')
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\axes\_base.py:2521, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2519     # Update from data if axis is already set but no unit is set yet.
#    2520     if axis is not None and data is not None and not axis.have_units():
# -> 2521         axis.update_units(data)
#    2522 for axis_name, axis in axis_map.items():
#    2523     # Return if no axis is set.
#    2524     if axis is None:
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\axis.py:1449, in Axis.update_units(self, data)
#    1447 neednew = self.converter != converter
#    1448 self.converter = converter
# -> 1449 default = self.converter.default_units(data, self)
#    1450 if default is not None and self.units is None:
#    1451     self.set_units(default)
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File D:\Programas\Anaconda\lib\site-packages\matplotlib\category.py:225, in UnitData.update(self, data)
#     223 # check if convertible to number:
#     224 convertible = True
# --> 225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
#     227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'numpy.ndarray'
